# %%
# %matplotlib inline

# Load the machine
import os
from os.path import join
from os import makedirs
from copy import deepcopy
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR
import matplotlib.pyplot as plt

from util.simulation import *
from util.failures import *
from IPython.display import display, HTML

# %% [markdown]
# machine avec defaut de court circuitr 1 tours

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Court_Circuit_1_Tours.json"

# Chargement de la machine
IPMSM_A = load(path)

fig, ax = IPMSM_A.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Circuit1 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Court_Circuit_1_Tours.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Circuit1 = load_simulation(name="Circuit1", machine=machine_Circuit1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Circuit1 = simu_Circuit1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Circuit1,
    legend_list=["Tesla_model_3_ref", "Defaut_Court_Circuit_1_Tours"]
)

# %%
out_Circuit1.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Court_Circuit_1_Tours', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Court_Circuit_2_Tours.json"

# Chargement de la machine
IPMSM_B = load(path)

fig, ax = IPMSM_B.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Circuit2 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Court_Circuit_2_Tours.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Circuit2 = load_simulation(name="Circuit2", machine=machine_Circuit2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Circuit2 = simu_Circuit2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Circuit2,
    legend_list=["Tesla_model_3_ref", "Defaut_Court_Circuit_2_Tours"]
)

# %%
out_Circuit2.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Court_Circuit_2_Tours', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------
------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #Visualisation de machine avec defaut de demagnetisation
#
# Avec ce defaut, les aimants n’arrivent plus à fournir le champ magnétique qu’ils donnaient au départ  c.a.d la machine perd en performance.
#
# Conséquences :
#     - Baisse du couple produit -> le moteur devient moins puissant.
#     - Déséquilibre magnétique -> vibrations ou bruit.
#     - Surconsommation -> il faut plus de courant pour obtenir le même couple.
#     - Surchauffe -> car la machine travaille “plus fort” pour compenser.
#
# nous avons ici generer des machines avec defaut de demagnetisation partant de 2% to 60/70%

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_2_Pourcent.json"

# Chargement de la machine
IPMSM_C = load(path)

fig, ax = IPMSM_C.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Demagnetisation1 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_2_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Demagnetisation1 = load_simulation(name="Demagnetisation1", machine=machine_Demagnetisation1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Demagnetisation1 = simu_Demagnetisation1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Demagnetisation1,
    legend_list=["Tesla_model_3_ref", "Demagnetisation_2_Pourcent"]
)

# %%
out_Demagnetisation1.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Demagnetisation_2_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
# %matplotlib inline

# 1) Chargement 
print("=" * 80)
print("COMPARAISON DÉMAGNÉTISATION - MACHINE RÉFÉRENCE vs DÉMAGNÉTISATION 2%")
print("=" * 80)

# Machine de référence
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))

# Machine avec défaut de démagnétisation
machine_Demagnetisation1 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_2_Pourcent.json")

print(" Machines chargées avec succès")

# 2) Analyse comparative des propriétés magnétiques
print("\n ANALYSE COMPARATIVE DES PROPRIÉTÉS MAGNÉTIQUES")
print("=" * 60)

def compare_magnet_properties(machine1, machine2, name1, name2):
    """Compare les propriétés magnétiques de deux machines"""
    
    print(f"\n COMPARAISON: {name1} vs {name2}")
    print("-" * 70)
    
    # === STATOR (inchangé) ===
    print("\n  STATOR:")
    print(f"   Rayon interne: {machine1.stator.Rint*1000:.2f} mm -> {machine2.stator.Rint*1000:.2f} mm")
    print(f"   Rayon externe: {machine1.stator.Rext*1000:.2f} mm -> {machine2.stator.Rext*1000:.2f} mm")
    print(f"   Longueur: {machine1.stator.L1*1000:.2f} mm -> {machine2.stator.L1*1000:.2f} mm")
    
    # === ROTOR (inchangé) ===
    print(f"\n  ROTOR:")
    print(f"   Rayon interne: {machine1.rotor.Rint*1000:.2f} mm -> {machine2.rotor.Rint*1000:.2f} mm")
    print(f"   Rayon externe: {machine1.rotor.Rext*1000:.2f} mm -> {machine2.rotor.Rext*1000:.2f} mm")
    print(f"   Longueur: {machine1.rotor.L1*1000:.2f} mm -> {machine2.rotor.L1*1000:.2f} mm")
    
    # Entrefer
    airgap1 = machine1.stator.Rint - machine1.rotor.Rext
    airgap2 = machine2.stator.Rint - machine2.rotor.Rext
    airgap_variation = (airgap2 - airgap1) / airgap1 * 100
    print(f"\n   ENTREFER: {airgap1*1000:.3f} mm -> {airgap2*1000:.3f} mm ({airgap_variation:+.2f}%)")
    
    # === AIMANTS - ANALYSE DÉTAILLÉE ===
    print(f"\n  AIMANTS - ANALYSE DÉMAGNÉTISATION:")
    print("=" * 50)
    
    if hasattr(machine1.rotor, 'hole') and hasattr(machine2.rotor, 'hole'):
        print(f" Nombre de trous: {len(machine1.rotor.hole)} -> {len(machine2.rotor.hole)}")
        
        total_br_variation = 0
        total_brm20_variation = 0
        total_hc_variation = 0
        magnet_count = 0
        
        for i, (hole1, hole2) in enumerate(zip(machine1.rotor.hole, machine2.rotor.hole)):
            print(f"\n   TROU {i+1} ({type(hole1).__name__}):")
            
            # Analyse des aimants via magnet_dict
            if hasattr(hole1, 'magnet_dict') and hasattr(hole2, 'magnet_dict'):
                magnets1 = hole1.magnet_dict
                magnets2 = hole2.magnet_dict
                
                print(f"     Aimants disponibles: {list(magnets1.keys())}")
                
                for magnet_name in magnets1.keys():
                    if magnet_name in magnets2:
                        magnet1 = magnets1[magnet_name]
                        magnet2 = magnets2[magnet_name]
                        
                        if (magnet1 is not None and magnet2 is not None and 
                            hasattr(magnet1, 'mat_type') and hasattr(magnet2, 'mat_type')):
                            
                            if (hasattr(magnet1.mat_type, 'mag') and 
                                hasattr(magnet2.mat_type, 'mag')):
                                
                                mag1 = magnet1.mat_type.mag
                                mag2 = magnet2.mat_type.mag
                                
                                print(f"\n     {magnet_name.upper()}:")
                                print(f"       Type: {type(magnet1).__name__}")
                                
                                # === PROPRIÉTÉS MAGNÉTIQUES ===
                                
                                # Brm20 (Induction rémanente à 20°C) - PROPRIÉTÉ PRINCIPALE
                                if hasattr(mag1, 'Brm20') and hasattr(mag2, 'Brm20'):
                                    brm20_1 = mag1.Brm20
                                    brm20_2 = mag2.Brm20
                                    brm20_variation = (brm20_2 - brm20_1) / brm20_1 * 100
                                    total_brm20_variation += brm20_variation
                                    magnet_count += 1
                                    
                                    print(f"   Brm20 (Br à 20°C):")
                                    print(f"    Référence: {brm20_1:.4f} T")
                                    print(f"    Démagnétisé: {brm20_2:.4f} T")
                                    print(f"    Variation: {brm20_variation:+.2f}%")
                                    
                                    if abs(brm20_variation + 2.0) < 0.1:
                                        print(f"  Démagnétisation de 2% confirmée")
                                    elif abs(brm20_variation) < 0.01:
                                        print(f" Aucune démagnétisation détectée")
                                    else:
                                        print(f"  Démagnétisation différente de 2% attendu")
                                
                                # Br (Induction rémanente)
                                if hasattr(mag1, 'Br') and hasattr(mag2, 'Br'):
                                    br1 = mag1.Br
                                    br2 = mag2.Br
                                    br_variation = (br2 - br1) / br1 * 100
                                    total_br_variation += br_variation
                                    
                                    print(f"   Br (Induction rémanente):")
                                    print(f"   Référence: {br1:.4f} T")
                                    print(f"    Démagnétisé: {br2:.4f} T")
                                    print(f"    Variation: {br_variation:+.2f}%")
                                
                                # Hc (Champ coercitif)
                                if hasattr(mag1, 'Hc') and hasattr(mag2, 'Hc'):
                                    hc1 = mag1.Hc
                                    hc2 = mag2.Hc
                                    hc_variation = (hc2 - hc1) / hc1 * 100 if hc1 != 0 else 0
                                    total_hc_variation += hc_variation
                                    
                                    print(f"   Hc (Champ coercitif):")
                                    print(f"    Référence: {hc1:.0f} A/m")
                                    print(f"    Démagnétisé: {hc2:.0f} A/m")
                                    print(f"    Variation: {hc_variation:+.2f}%")
                                
                                # mur_lin (Perméabilité relative linéaire)
                                if hasattr(mag1, 'mur_lin') and hasattr(mag2, 'mur_lin'):
                                    mur1 = mag1.mur_lin
                                    mur2 = mag2.mur_lin
                                    mur_variation = (mur2 - mur1) / mur1 * 100 if mur1 != 0 else 0
                                    
                                    print(f"   μr_lin (Perméabilité relative):")
                                    print(f"   Référence: {mur1:.3f}")
                                    print(f"   Démagnétisé: {mur2:.3f}")
                                    print(f"   Variation: {mur_variation:+.2f}%")
                                
                                # === DIMENSIONS DES AIMANTS ===
                                print(f"   DIMENSIONS:")
                                
                                if hasattr(magnet1, 'Hmag') and hasattr(magnet2, 'Hmag'):
                                    hmag1 = magnet1.Hmag * 1000  # en mm
                                    hmag2 = magnet2.Hmag * 1000  # en mm
                                    hmag_variation = (hmag2 - hmag1) / hmag1 * 100
                                    print(f"  Épaisseur: {hmag1:.3f} mm -> {hmag2:.3f} mm ({hmag_variation:+.2f}%)")
                                
                                if hasattr(magnet1, 'Wmag') and hasattr(magnet2, 'Wmag'):
                                    wmag1 = magnet1.Wmag * 1000  # en mm
                                    wmag2 = magnet2.Wmag * 1000  # en mm
                                    wmag_variation = (wmag2 - wmag1) / wmag1 * 100
                                    print(f"   Largeur: {wmag1:.3f} mm -> {wmag2:.3f} mm ({wmag_variation:+.2f}%)")
                                
                                if hasattr(magnet1, 'Lmag') and hasattr(magnet2, 'Lmag'):
                                    lmag1 = magnet1.Lmag * 1000  # en mm
                                    lmag2 = magnet2.Lmag * 1000  # en mm
                                    lmag_variation = (lmag2 - lmag1) / lmag1 * 100
                                    print(f"  Longueur: {lmag1:.3f} mm -> {lmag2:.3f} mm ({lmag_variation:+.2f}%)")
                            else:
                                print(f"  Pas de propriétés magnétiques trouvées")
                        else:
                            print(f"  Aimant non trouvé ou structure différente")
                    else:
                        print(f" {magnet_name} non trouvé dans la machine de référence")
        
        # Résumé de la démagnétisation
        if magnet_count > 0:
            avg_brm20_variation = total_brm20_variation / magnet_count
            avg_br_variation = total_br_variation / magnet_count
            avg_hc_variation = total_hc_variation / magnet_count
            
            print(f"\n   RÉSUMÉ DÉMAGNÉTISATION:")
            print(f"   Nombre d'aimants analysés: {magnet_count}")
            print(f"   Variation moyenne Brm20: {avg_brm20_variation:+.2f}%")
            print(f"   Variation moyenne Br: {avg_br_variation:+.2f}%")
            print(f"   Variation moyenne Hc: {avg_hc_variation:+.2f}%")
            
            if abs(avg_brm20_variation + 2.0) < 0.1:
                print(f"   Démagnétisation de 2% confirmée globalement")
            elif abs(avg_brm20_variation) < 0.01:
                print(f"   Aucune démagnétisation détectée")
            else:
                print(f"  Démagnétisation différente de 2% attendu")
        else:
            print(f"  Aucun aimant trouvé pour l'analyse")
    else:
        print(f"  Pas de trous trouvés dans le rotor")

# Comparaison des propriétés magnétiques
compare_magnet_properties(machine_ref, machine_Demagnetisation1, "Référence", "Démagnétisation 2%")

# 3) Vérification alternative - analyse directe des fichiers JSON
print(f"\n VÉRIFICATION ALTERNATIVE - ANALYSE FICHIERS JSON")
print("=" * 60)

import json

def analyze_json_magnets_detailed(file_path, name):
    """Analyse détaillée des propriétés magnétiques dans un fichier JSON"""
    print(f"\n ANALYSE DÉTAILLÉE {name}:")
    print(f" Fichier: {file_path}")
    
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
        
        if 'rotor' in data and 'hole' in data['rotor']:
            holes = data['rotor']['hole']
            print(f" Nombre de trous: {len(holes)}")
            
            for i, hole in enumerate(holes):
                print(f"\n TROU {i+1}:")
                if 'magnet_dict' in hole:
                    magnets = hole['magnet_dict']
                    print(f"   Aimants trouvés: {list(magnets.keys())}")
                    
                    for magnet_name, magnet_data in magnets.items():
                        print(f"\n   {magnet_name.upper()}:")
                        if 'mat_type' in magnet_data and 'mag' in magnet_data['mat_type']:
                            mag_data = magnet_data['mat_type']['mag']
                            print(f"     Propriétés magnétiques disponibles: {list(mag_data.keys())}")
                            
                            # valeurs importantes
                            for prop in ['Brm20', 'Br', 'Hc', 'mur_lin']:
                                if prop in mag_data:
                                    print(f"     {prop}: {mag_data[prop]}")
                        else:
                            print(f"     Pas de propriétés magnétiques trouvées")
                else:
                    print(f"   Pas de magnet_dict trouvé")
        else:
            print(f" Structure de rotor non trouvée")
            
    except Exception as e:
        print(f" Erreur lors de l'analyse: {e}")

# analyse des deux fichiers en détail
analyze_json_magnets_detailed(join(DATA_DIR, "Machine", "Tesla_model_3.json"), "RÉFÉRENCE")
analyze_json_magnets_detailed("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_2_Pourcent.json", "DÉMAGNÉTISATION 2%")

# 4) Conclusion
print(f"\n CONCLUSION")
print("=" * 20)

print(" RÉSULTATS DE LA COMPARAISON:")
print("   - Vérification des propriétés magnétiques Brm20, Br, Hc")
print("   - Comparaison des dimensions des aimants")
print("   - Analyse de la cohérence des variations")
print("   - Détection des différences entre les machines")

print("\n" + "=" * 80)
print(" COMPARAISON DÉMAGNÉTISATION TERMINÉE")
print("=" * 80)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chemin 
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_70_Pourcent.json"

# Chargement de la machine
IPMSM_D = load(path)

fig, ax = IPMSM_D.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Demagnetisation2 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Demagnetisation_70_Pourcent.json"
)

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Demagnetisation2 = load_simulation(name="Demagnetisation2", machine=machine_Demagnetisation2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Demagnetisation2 = simu_Demagnetisation2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Demagnetisation2,
    legend_list=["Tesla_model_3_ref", "Demagnetisation_70_Pourcent"]
)

# %%
out_Demagnetisation2.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Demagnetisation_70_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------
------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #defaut d'excentricite:
#
# L’entrefer (l’espace entre rotor et stator) n’a plus la même taille tout autour.
#
# Conséquences:
#
#     - Couple et flux déséquilibrés -> vibrations, bruit.
#     - Harmoniques supplémentaires dans les courants.
#     - Surchauffe localisée (là où l’entrefer est trop petit).
#     - Peut mener à un frottement rotor-stator si l’entrefer devient nul d’un côté.

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Excentricite_0.02mm.json"

# Chargement de la machine
IPMSM_E = load(path)

fig, ax = IPMSM_E.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Demagnetisation1 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Excentricite_0.02mm.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Excentricite1 = load_simulation(name="Excentricite1", machine=machine_Excentricite1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Excentricite1 = simu_Excentricite1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Excentricite1,
    legend_list=["Tesla_model_3_ref", "Defaut_Excentricite_0.02mm"]
)

# %%
out_Excentricite1.save(save_path='Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Defaut_Excentricite_0.02mmm', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Excentricite_0.15mm.json"

# Chargement de la machine
IPMSM_F = load(path)

fig, ax = IPMSM_F.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Excentricite2 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Excentricite_0.15mm.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Excentricite2 = load_simulation(name="Excentricite2", machine=machine_Excentricite2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Excentricite2 = simu_Excentricite2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Excentricite2,
    legend_list=["Tesla_model_3_ref", "Machine_Excentricite_0.15mm"]
)

# %%
out_Excentricite2.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Excentricite_0.15mm', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------
------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Defaut materiau:
#
# dans une machine électrique cela  correspond au cas où le matériau utilisé (aimants, tôles du stator ou du rotor) n’a pas les propriétés magnétiques prévues. c.a.d en d'autres terme que la machine n’a pas le comportement électromagnétique attendu, car son matériau est de moins bonne qualité ou a été altéré.
#
# Conséquences:
#      - Baisse du couple disponible (car champ magnétique moins fort(Br, HC, Ur)).
#      - Consommation plus élevée (il faut plus de courant pour compenser).
#      - Echauffement anormal (pertes fer accrues).
#      - Dans le cas d’un défaut localisé -> déséquilibre magnétique et vibrations.

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Materiau_Moins2.0_Pourcent.json"

# Chargement de la machine
IPMSM_G = load(path)

fig, ax = IPMSM_G.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_materiau1 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Materiau_Moins2.0_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_materiau1 = load_simulation(name="materiau1", machine=machine_materiau1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_materiau1 = simu_materiau1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_materiau1,
    legend_list=["Tesla_model_3_ref", "Defaut_Materiau2.0_Pourcent"]
)

# %%
out_materiau1.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Materiau2.0_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Materiau_Plus8.0_Pourcent.json"

# Chargement de la machine
IPMSM_H = load(path)

fig, ax = IPMSM_H.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_materiau2 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Materiau_Plus8.0_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_materiau2 = load_simulation(name="materiau2", machine=machine_materiau2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_materiau2 = simu_materiau2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_materiau2,
    legend_list=["Tesla_model_3_ref", "Defaut_Materiau_8.0_Pourcent"]
)

# %%
out_materiau2.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Materiau_8.0_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
--------------------------------------------------------------------------------------------------------------------------------
-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Defaut Usinage:
#
# ceci correspond à une erreur de fabrication mécanique lors de la production du stator, du rotor, des encoches ou même des aimants.
# Concrètement, les dimensions (largeur, profondeur, angle, épaisseur…) ne correspondent pas exactement aux plans.
#
# Conséquences:
#  - Variation des performances : couple plus faible ou bruit électromagnétique accru.
#  - Harmoniques supplémentaires dans le flux et le courant.
#  - Vibrations dues à l’asymétrie.
#  - Dans les cas graves : frottement rotor/stator.

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Usinage_Moins0.5_Pourcent.json"

# Chargement de la machine
IPMSM_I = load(path)

fig, ax = IPMSM_I.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Usinage1 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Usinage_Moins0.5_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Usinage1 = load_simulation(name="Usinage1", machine=machine_Usinage1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Usinage1 = simu_Usinage1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Usinage1,
    legend_list=["Tesla_model_3_ref", "Defaut_Usinage_Moins0.5_Pourcent"]
)

# %%
out_Usinage1.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Usinage_Moins0.5_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Usinage_Plus5.0_Pourcent.json"

# Chargement de la machine
IPMSM_J = load(path)

fig, ax = IPMSM_J.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Usinage2 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Usinage_Plus5.0_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Usinage2 = load_simulation(name="Usinage2", machine=machine_Usinage2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Usinage2 = simu_Usinage2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Usinage2,
    legend_list=["Tesla_model_3_ref", "Defaut_Usinage_Plus5.0_Pourcent"]
)

# %%
out_Usinage2.save(save_path='Tesla_Model3_Dataset_Cohérent_100/simulation_result_machine/machine-defect/Defaut_Usinage_Plus5.0_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
# %matplotlib inline

# 1) Chargement des machines
print("=" * 80)
print("COMPARAISON MACHINE RÉFÉRENCE vs DÉFAUT USINAGE +10%")
print("=" * 80)

# Machine de référence
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))

# Machine avec défaut d'usinage
machine_Usinage2 = load("Tesla_Model3_Dataset_Cohérent_100/Variantes_Defauts/Tesla_Model3_Defaut_Usinage_Plus10_Pourcent.json")

print(" Machines chargées avec succès")

# 2) Analyse comparative des paramètres géométriques
print("\n ANALYSE COMPARATIVE DES PARAMÈTRES")
print("=" * 50)

def compare_machine_parameters(machine1, machine2, name1, name2):
    """Compare les paramètres de deux machines"""
    
    print(f"\n COMPARAISON: {name1} vs {name2}")
    print("-" * 60)
    
    # === STATOR ===
    print("\n  STATOR:")
    print(f"   Rayon interne: {machine1.stator.Rint*1000:.2f} mm -> {machine2.stator.Rint*1000:.2f} mm")
    print(f"   Rayon externe: {machine1.stator.Rext*1000:.2f} mm -> {machine2.stator.Rext*1000:.2f} mm")
    print(f"   Longueur: {machine1.stator.L1*1000:.2f} mm -> {machine2.stator.L1*1000:.2f} mm")
    
    # Encoches stator - Analyse des coordonnées SlotUD
    if hasattr(machine1.stator, 'slot') and hasattr(machine2.stator, 'slot'):
        slot1 = machine1.stator.slot
        slot2 = machine2.stator.slot
        
        print(f"\n   ENCOCHES STATOR (SlotUD):")
        print(f"   Nombre d'encoches: {slot1.Zs} -> {slot2.Zs}")
        
        # Analyser les coordonnées des segments
        if hasattr(slot1, 'line_list') and hasattr(slot2, 'line_list'):
            print(f"   Nombre de segments: {len(slot1.line_list)} -> {len(slot2.line_list)}")
            
            # Comparer les coordonnées des premiers segments
            for i, (line1, line2) in enumerate(zip(slot1.line_list[:3], slot2.line_list[:3])):
                if hasattr(line1, 'begin') and hasattr(line2, 'begin'):
                    # Coordonnées de début
                    x1_begin = line1.begin.real * 1000  # en mm
                    y1_begin = line1.begin.imag * 1000  # en mm
                    x2_begin = line2.begin.real * 1000  # en mm
                    y2_begin = line2.begin.imag * 1000  # en mm
                    
                    # Calcul des variations
                    x_variation = (x2_begin - x1_begin) / x1_begin * 100
                    y_variation = (y2_begin - y1_begin) / y1_begin * 100 if y1_begin != 0 else 0
                    
                    print(f"   Segment {i+1} début:")
                    print(f"     X: {x1_begin:.3f} mm -> {x2_begin:.3f} mm ({x_variation:+.2f}%)")
                    print(f"     Y: {y1_begin:.3f} mm -> {y2_begin:.3f} mm ({y_variation:+.2f}%)")
                
                if hasattr(line1, 'end') and hasattr(line2, 'end'):
                    # Coordonnées de fin
                    x1_end = line1.end.real * 1000  # en mm
                    y1_end = line1.end.imag * 1000  # en mm
                    x2_end = line2.end.real * 1000  # en mm
                    y2_end = line2.end.imag * 1000  # en mm
                    
                    # Calcul des variations
                    x_variation = (x2_end - x1_end) / x1_end * 100
                    y_variation = (y2_end - y1_end) / y1_end * 100 if y1_end != 0 else 0
                    
                    print(f"   Segment {i+1} fin:")
                    print(f"     X: {x1_end:.3f} mm -> {x2_end:.3f} mm ({x_variation:+.2f}%)")
                    print(f"     Y: {y1_end:.3f} mm -> {y2_end:.3f} mm ({y_variation:+.2f}%)")
    
    # Bobinage
    if hasattr(machine1.stator, 'winding') and hasattr(machine2.stator, 'winding'):
        wind1 = machine1.stator.winding
        wind2 = machine2.stator.winding
        
        print(f"\n   BOBINAGE:")
        if hasattr(wind1, 'Ntcoil') and hasattr(wind2, 'Ntcoil'):
            print(f"   Tours par bobine: {wind1.Ntcoil} -> {wind2.Ntcoil}")
        if hasattr(wind1, 'Npcp') and hasattr(wind2, 'Npcp'):
            print(f"   Paires de pôles: {wind1.Npcp} -> {wind2.Npcp}")
    
    # === ROTOR ===
    print(f"\n ROTOR:")
    print(f"   Rayon interne: {machine1.rotor.Rint*1000:.2f} mm -> {machine2.rotor.Rint*1000:.2f} mm")
    print(f"   Rayon externe: {machine1.rotor.Rext*1000:.2f} mm -> {machine2.rotor.Rext*1000:.2f} mm")
    print(f"   Longueur: {machine1.rotor.L1*1000:.2f} mm -> {machine2.rotor.L1*1000:.2f} mm")
    
    # Entrefer
    airgap1 = machine1.stator.Rint - machine1.rotor.Rext
    airgap2 = machine2.stator.Rint - machine2.rotor.Rext
    airgap_variation = (airgap2 - airgap1) / airgap1 * 100
    print(f"\n   ENTREFER: {airgap1*1000:.3f} mm -> {airgap2*1000:.3f} mm ({airgap_variation:+.2f}%)")
    
    # === AIMANTS ===
    if hasattr(machine1.rotor, 'hole') and hasattr(machine2.rotor, 'hole'):
        print(f"\n AIMANTS:")
        
        for i, (hole1, hole2) in enumerate(zip(machine1.rotor.hole, machine2.rotor.hole)):
            print(f"   TROU {i+1}:")
            
            for attr_name in dir(hole1):
                if attr_name.startswith('magnet_'):
                    magnet1 = getattr(hole1, attr_name)
                    magnet2 = getattr(hole2, attr_name)
                    
                    if magnet1 is not None and magnet2 is not None:
                        if hasattr(magnet1, 'mat_type') and hasattr(magnet2, 'mat_type'):
                            if hasattr(magnet1.mat_type, 'mag') and hasattr(magnet2.mat_type, 'mag'):
                                if hasattr(magnet1.mat_type.mag, 'Br') and hasattr(magnet2.mat_type.mag, 'Br'):
                                    br1 = magnet1.mat_type.mag.Br
                                    br2 = magnet2.mat_type.mag.Br
                                    br_variation = (br2 - br1) / br1 * 100
                                    print(f"     Br: {br1:.3f} T -> {br2:.3f} T ({br_variation:+.2f}%)")
                                
                                if hasattr(magnet1.mat_type.mag, 'Hc') and hasattr(magnet2.mat_type.mag, 'Hc'):
                                    hc1 = magnet1.mat_type.mag.Hc
                                    hc2 = magnet2.mat_type.mag.Hc
                                    hc_variation = (hc2 - hc1) / hc1 * 100
                                    print(f"     Hc: {hc1:.3f} A/m -> {hc2:.3f} A/m ({hc_variation:+.2f}%)")
                        
                        # Dimensions des aimants
                        if hasattr(magnet1, 'Hmag') and hasattr(magnet2, 'Hmag'):
                            hmag1 = magnet1.Hmag * 1000  # en mm
                            hmag2 = magnet2.Hmag * 1000  # en mm
                            hmag_variation = (hmag2 - hmag1) / hmag1 * 100
                            print(f"     Épaisseur: {hmag1:.3f} mm -> {hmag2:.3f} mm ({hmag_variation:+.2f}%)")
                        
                        if hasattr(magnet1, 'Wmag') and hasattr(magnet2, 'Wmag'):
                            wmag1 = magnet1.Wmag * 1000  # en mm
                            wmag2 = magnet2.Wmag * 1000  # en mm
                            wmag_variation = (wmag2 - wmag1) / wmag1 * 100
                            print(f"     Largeur: {wmag1:.3f} mm -> {wmag2:.3f} mm ({wmag_variation:+.2f}%)")

# Comparaison des paramètres
compare_machine_parameters(machine_ref, machine_Usinage2, "Référence", "Défaut Usinage +10%")

# 3) Visualisation géométrique comparative
print(f"\n VISUALISATION GÉOMÉTRIQUE COMPARATIVE")
print("=" * 50)

fig, axes = plt.subplots(1, 2, figsize=(20, 10))

# Machine de référence
axes[0].set_title("Machine de Référence\n(Tesla Model 3)", fontsize=14, fontweight='bold')
machine_ref.plot(ax=axes[0], is_show_fig=False)
axes[0].set_aspect('equal')

# Machine avec défaut d'usinage
axes[1].set_title("Machine avec Défaut Usinage +10%\n(Encoches élargies)", fontsize=14, fontweight='bold')
machine_Usinage2.plot(ax=axes[1], is_show_fig=False)
axes[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# 4) Analyse des différences visuelles
print(f"\n  DIFFÉRENCES VISUELLES OBSERVABLES")
print("=" * 45)

print(" OBSERVATIONS:")
print("   - Encoches stator plus larges dans la machine avec défaut")
print("   - Géométrie des segments modifiée")
print("   - Coordonnées X des segments augmentées de +10%")
print("   - Entrefer potentiellement modifié")

# 5) Calcul des variations quantitatives
print(f"\n VARIATIONS QUANTITATIVES")
print("=" * 35)

# Calcul des variations des encoches SlotUD
if hasattr(machine_ref.stator, 'slot') and hasattr(machine_Usinage2.stator, 'slot'):
    slot_ref = machine_ref.stator.slot
    slot_defect = machine_Usinage2.stator.slot
    
    if hasattr(slot_ref, 'line_list') and hasattr(slot_defect, 'line_list'):
        print(f" ANALYSE DES COORDONNÉES SLOTUD:")
        
        # Analyser le premier segment pour voir la variation
        line_ref = slot_ref.line_list[0]
        line_defect = slot_defect.line_list[0]
        
        if hasattr(line_ref, 'begin') and hasattr(line_defect, 'begin'):
            x_ref = line_ref.begin.real * 1000  # en mm
            x_defect = line_defect.begin.real * 1000  # en mm
            x_variation = (x_defect - x_ref) / x_ref * 100
            
            print(f" Coordonnée X du premier segment:")
            print(f"   Référence: {x_ref:.3f} mm")
            print(f"   Défaut: {x_defect:.3f} mm")
            print(f"   Variation: {x_variation:+.2f}%")
            
            if abs(x_variation - 10.0) < 0.1:
                print(f"  Variation conforme au défaut de +10%")
            else:
                print(f"  Variation différente de +10% attendu")

# 6) Impact sur l'entrefer
airgap_ref = machine_ref.stator.Rint - machine_ref.rotor.Rext
airgap_defect = machine_Usinage2.stator.Rint - machine_Usinage2.rotor.Rext
airgap_variation = (airgap_defect - airgap_ref) / airgap_ref * 100

print(f"\n ENTREFER:")
print(f"  Référence: {airgap_ref*1000:.3f} mm")
print(f"  Défaut: {airgap_defect*1000:.3f} mm")
print(f"  Variation: {airgap_variation:+.2f}%")

if abs(airgap_variation) < 1.0:
    print(f"  Entrefer peu affecté par le défaut d'usinage")
else:
    print(f"  Entrefer modifié par le défaut d'usinage")

# 7) Résumé de la comparaison
print(f"\n RÉSUMÉ DE LA COMPARAISON")
print("=" * 35)

print(" DÉFAUT USINAGE +10% DÉTECTÉ:")
print("   - Coordonnées X des segments d'encoches augmentées")
print("   - Géométrie des encoches modifiée")
print("   - Impact visuel sur la forme des encoches")
print("   - Entrefer potentiellement affecté")

print("\n" + "=" * 80)
print(" COMPARAISON TERMINÉE")
print("=" * 80)

# %%
------------------------------------------------------------------------------------------------------------------------------
------------------------------------------------------------------------------------------------------------------------------

# %%
------------------------------------MACHINE SAINE-------------------------------------------

# %% [markdown]
# #machine avec modification des aimants
#
#  VARIATIONS NÉGATIVES (-0.6% à -5.0%) :
#     - Aimants plus petits -> Volume magnétique réduit
#     - Flux magnétique diminué -> Couple électromagnétique réduit
#     - Induction dans l'entrefer réduite -> Performances dégradées
#
#  VARIATIONS POSITIVES (+0.6% à +5.0%) :
#     - Aimants plus gros -> Volume magnétique augmenté
#     - Flux magnétique augmenté -> Couple électromagnétique augmenté
#     - Induction dans l'entrefer augmentée -> Performances améliorées

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Moins0.6_Pourcent.json"

# Chargement de la machine
IPMSM_K = load(path)

fig, ax = IPMSM_K.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Aimant1 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Moins0.6_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Aimant1 = load_simulation(name="Aimant1", machine=machine_Aimant1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Aimant1= simu_Aimant1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Aimant1,
    legend_list=["Tesla_model_3_ref", "Machine_Aimants_Moins0.6_Pourcent"]
)

# %%
out_Aimant1.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-saine/Aimants_Moins0.6_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Plus5.0_Pourcent.json"

# Chargement de la machine
IPMSM_L = load(path)

fig, ax = IPMSM_L.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Aimant2 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Plus5.0_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Aimant2 = load_simulation(name="Aimant2", machine=machine_Aimant2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Aimant2= simu_Aimant2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Aimant2,
    legend_list=["Tesla_model_3_ref", "Machine_Aimants_Plus5.0_Pourcent"]
)

# %%
out_Aimant2.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-saine/Aimants_Plus5.0_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
# Charger tes deux fichiers
M1 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Moins0.6_Pourcent.json")
M2 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Plus5.0_Pourcent.json")

# Compareson des paramètres importants
print("Entrefer M1:", M1.stator.Rint - M1.rotor.Rext)
print("Entrefer M2:", M2.stator.Rint - M2.rotor.Rext)

print("Tours par bobine M1:", M1.stator.winding.Ntcoil)
print("Tours par bobine M2:", M2.stator.winding.Ntcoil)

print("Largeur encoche M1:", M1.stator.slot.W0)
print("Largeur encoche M2:", M2.stator.slot.W0)

# cas particulieur sur  les aimants du rotor
for i, (h1, h2) in enumerate(zip(M1.rotor.hole, M2.rotor.hole)):
    if hasattr(h1, "magnet_0") and hasattr(h2, "magnet_0"):
        if h1.magnet_0 and h2.magnet_0:
            print(f"Aimant {i} - Br M1: {h1.magnet_0.mat_type.mag.Br}, Br M2: {h2.magnet_0.mat_type.mag.Br}")

# %%
----------------------------------------------------------------------------------------------------
----------------------------------------------------------------------------------------------------

# %%
#machines generer avec encoches differents:

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Encoches_Moins0.3_Pourcent.json"

# Chargement de la machine
IPMSM_M = load(path)

fig, ax = IPMSM_M.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Encoches1= load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Encoches_Moins0.3_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Encoches1 = load_simulation(name="Encoches1", machine=machine_Encoches1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Encoches1= simu_Encoches1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Encoches1,
    legend_list=["Tesla_model_3_ref", "Machine_Encoches_Moins0.3_Pourcent"]
)

# %%
out_Encoches1.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-saine/Encoches_Moins0.3_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
---------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Encoches_Plus3.0_Pourcent.json"

# Chargement de la machine
IPMSM_N = load(path)

fig, ax = IPMSM_N.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chargement des machines pour la simulation 
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_Encoches2= load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Encoches_Plus3.0_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)

simu_Encoches2 = load_simulation(name="Encoche2", machine=machine_Encoches2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_Encoches2= simu_Encoches2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_Encoches2,
    legend_list=["Tesla_model_3_ref", "Machine_Encoches_Plus3.0_Pourcent"]
)

# %%
out_Encoches2.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine-saine/Encoches_Plus3.0_Pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
---------------------------------------------------------------------------------------------------------
-----------------------------------------------------------------------------------------------------

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Spires_Moins1_Tours.json"

# Chargement de la machine
IPMSM_O = load(path)

fig, ax = IPMSM_O.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()

# %%
# Chemin du fichier
path = "Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Spires_Plus3_Tours.json"

# Chargement de la machine
IPMSM_P = load(path)

fig, ax = IPMSM_P.plot(is_show_fig=False)

# Affichage de nom complet du fichier 
filename = os.path.splitext(os.path.basename(path))[0]
fig.suptitle(filename, fontsize=12)

plt.show()
