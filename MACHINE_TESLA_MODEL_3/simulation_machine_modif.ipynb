# %%
# %matplotlib inline

# Load the machine
from os.path import join
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR
from util.simulation import *
from util.failures import *
from IPython.display import display, HTML

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_modif1 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Moins0.6_Pourcent.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)


simu_modif1 = load_simulation(name="modif1", machine=machine_modif1, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_modif1 = simu_modif1.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_modif1,
    legend_list=["TESLA_model_3_Ref", "Tesla_Model3_Saine_Aimants_Moins0.6_Pourcent"]
)

# %%
out_ref.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine_ref', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_modif1.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine_saine_aimants_moins0.6_pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
---------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Tesla_model_3.json"))
machine_modif2 = load("Tesla_Model3_modif_Cohérent_100/Variantes_Saines/Tesla_Model3_Saine_Aimants_Moins1.7_Pourcent.json")

# %%
 simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)


simu_modif2 = load_simulation(name="modif", machine=machine_modif2, rotor_speed=3000, stop=1, num_steps=4000)

# %%
# %matplotlib inline

out_ref = simu_ref.run()
out_modif2 = simu_modif2.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_modif2,
    legend_list=["TESLA_model_3_Ref", "Tesla_Model3_Saine_Aimants_Moins1.7_Pourcent"]
)

# %%
out_modif2.save(save_path='Tesla_Model3_modif_Cohérent_100/simulation_result_machine/machine_saine/machine_saine_aimants_moins1.7_pourcent', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
---------------------------------------------------------------------------------------------------------------------------

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
out_healthy17.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_17_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy18.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_18_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy19 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_19_Ntcoil_10.json")
machine_healthy20= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_20_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy19 = load_simulation(name="healthy19", machine=machine_healthy19, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy20 = load_simulation(name="healthy20", machine=machine_healthy20, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy19 = simu_healthy19.run()
out_healthy20 = simu_healthy20.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy19,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_19_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy20,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_20_Ntcoil_10"]
)

# %%
out_healthy19.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_19_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy20.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_20_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy21 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_21_Ntcoil_10.json")
machine_healthy22= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_22_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy21 = load_simulation(name="healthy21", machine=machine_healthy21, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy22 = load_simulation(name="healthy22", machine=machine_healthy22, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy21 = simu_healthy21.run()
out_healthy22 = simu_healthy22.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy21,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_21_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy22,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_22_Ntcoil_10"]
)

# %%
out_healthy21.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_21_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy22.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_22_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy23 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_23_Ntcoil_10.json")
machine_healthy24= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_24_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy23 = load_simulation(name="healthy23", machine=machine_healthy23, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy24 = load_simulation(name="healthy24", machine=machine_healthy24, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy23 = simu_healthy23.run()
out_healthy24 = simu_healthy24.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy23,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_23_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy24,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_24_Ntcoil_10"]
)

# %%
out_healthy23.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_23_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy24.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_24_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
--------------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy25 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_defect_25_Ntcoil_10.json")
machine_healthy26= load("machines_custom_batch_100_ntcoil/Toyota_Prius_defect_26_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy25 = load_simulation(name="healthy25", machine=machine_healthy25, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy26 = load_simulation(name="healthy26", machine=machine_healthy26, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy25 = simu_healthy25.run()
out_healthy26 = simu_healthy26.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy25,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_25_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy26,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_26_Ntcoil_10"]
)

# %%
out_healthy25.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_25_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy26.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_26_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
---------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy27 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_27_Ntcoil_10.json")
machine_healthy28= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_28_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy27 = load_simulation(name="healthy27", machine=machine_healthy27, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy28 = load_simulation(name="healthy28", machine=machine_healthy28, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy27 = simu_healthy27.run()
out_healthy28 = simu_healthy28.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy27,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_27_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy28,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_28_Ntcoil_10"]
)

# %%
out_healthy27.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_27_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy28.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_28_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy29 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_29_Ntcoil_10.json")
machine_healthy30= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_30_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy29 = load_simulation(name="healthy29", machine=machine_healthy29, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy30 = load_simulation(name="healthy30", machine=machine_healthy30, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy29 = simu_healthy29.run()
out_healthy30 = simu_healthy30.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy29,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_29_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy30,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_30_Ntcoil_10"]
)

# %%
out_healthy29.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_29_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy30.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_30_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy31 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_31_Ntcoil_10.json")
machine_healthy32= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_32_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy31 = load_simulation(name="healthy31", machine=machine_healthy31, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy32 = load_simulation(name="healthy32", machine=machine_healthy32, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy31 = simu_healthy31.run()
out_healthy32 = simu_healthy32.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy31,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_31_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy32,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_32_Ntcoil_10"]
)

# %%
out_healthy31.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_31_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy32.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_32_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy33 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_33_Ntcoil_10.json")
machine_healthy34= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_34_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy33 = load_simulation(name="healthy33", machine=machine_healthy33, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy34 = load_simulation(name="healthy34", machine=machine_healthy34, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy33 = simu_healthy33.run()
out_healthy34 = simu_healthy34.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy33,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_33_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy34,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_34_Ntcoil_10"]
)

# %%
out_healthy33.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_33_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy34.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_34_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy35 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_35_Ntcoil_10.json")
machine_healthy36= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_36_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy35 = load_simulation(name="healthy35", machine=machine_healthy35, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy36 = load_simulation(name="healthy36", machine=machine_healthy36, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy35 = simu_healthy35.run()
out_healthy36 = simu_healthy36.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy35,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_35_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy36,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_36_Ntcoil_10"]
)

# %%
out_healthy35.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_35_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy36.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_36_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy37 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_37_Ntcoil_10.json")
machine_healthy38= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_38_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy37 = load_simulation(name="healthy37", machine=machine_healthy37, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy38 = load_simulation(name="healthy38", machine=machine_healthy38, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy37 = simu_healthy37.run()
out_healthy38 = simu_healthy38.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy37,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_37_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy38,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_38_Ntcoil_10"]
)

# %%
out_healthy37.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_37_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy38.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_38_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy39 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_39_Ntcoil_10.json")
machine_healthy40= load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_40_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy39 = load_simulation(name="healthy39", machine=machine_healthy39, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy40 = load_simulation(name="healthy40", machine=machine_healthy40, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy39 = simu_healthy39.run()
out_healthy40 = simu_healthy40.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy39,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_39_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy40,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_40_Ntcoil_10"]
)

# %%
out_healthy39.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_39_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy40.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_40_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy41 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_41_Ntcoil_10.json")
machine_healthy42 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_42_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy41 = load_simulation(name="healthy41", machine=machine_healthy41, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy42 = load_simulation(name="healthy42", machine=machine_healthy42, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy41 = simu_healthy41.run()
out_healthy42 = simu_healthy42.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy41,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_41_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy42,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_42_Ntcoil_10"]
)

# %%
out_healthy41.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_41_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy42.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_42_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy43 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_43_Ntcoil_10.json")
machine_healthy44 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_44_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy43 = load_simulation(name="healthy43", machine=machine_healthy43, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy44 = load_simulation(name="healthy44", machine=machine_healthy44, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy43 = simu_healthy43.run()
out_healthy44 = simu_healthy44.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy43,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_43_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy44,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_44_Ntcoil_10"]
)

# %%
out_healthy43.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_43_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy44.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_44_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
------------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy45 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_45_Ntcoil_10.json")
machine_healthy46 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_46_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy45 = load_simulation(name="healthy45", machine=machine_healthy45, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy46 = load_simulation(name="healthy46", machine=machine_healthy46, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy45 = simu_healthy45.run()
out_healthy46 = simu_healthy46.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy45,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_45_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy46,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_46_Ntcoil_10"]
)

# %%
out_healthy45.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_45_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy46.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_46_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy47 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_47_Ntcoil_10.json")
machine_healthy48 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_48_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy47 = load_simulation(name="healthy47", machine=machine_healthy47, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy48 = load_simulation(name="healthy48", machine=machine_healthy48, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy47 = simu_healthy47.run()
out_healthy48 = simu_healthy48.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy47,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_47_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy48,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_48_Ntcoil_10"]
)

# %%
out_healthy47.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_47_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy48.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_48_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
-----------------------------------------------------------------------------------------------------------------------------

# %%
# Chargement des machines
machine_ref = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
machine_healthy49 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_49_Ntcoil_10.json")
machine_healthy50 = load("machines_custom_batch_100_ntcoil/Toyota_Prius_healthy_50_Ntcoil_10.json")

# %%
simu_ref = load_simulation(name="ref", machine=machine_ref, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy49 = load_simulation(name="healthy49", machine=machine_healthy49, rotor_speed=3000, stop=1, num_steps=4000)
simu_healthy50 = load_simulation(name="healthy50", machine=machine_healthy50, rotor_speed=3000, stop=1, num_steps=4000)

# %%
out_ref = simu_ref.run()
out_healthy49 = simu_healthy49.run()
out_healthy50 = simu_healthy50.run()

compare_simulation_results(
    out1=out_ref,
    out2=out_healthy49,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_49_Ntcoil_10"]
)
compare_simulation_results(
    out1=out_ref,
    out2=out_healthy50,
    legend_list=["Toyota_Prius_Ref", "Toyota_Prius_healthy_50_Ntcoil_10"]
)

# %%
out_healthy49.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_49_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
out_healthy50.save(save_path='machines_custom_batch_100_ntcoil/Machine_healthy/Ntcoil_10/compar_simule_healthy_50_ntcoil_10', is_folder=True, type_handle_old=2, type_compression=0)

# %%
--------------------------------------------------------------------------------------------------------------------------
--------------------------------------------------------------------------------------------------------------------------
