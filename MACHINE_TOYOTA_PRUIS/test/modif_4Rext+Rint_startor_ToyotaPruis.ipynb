# %%
# %matplotlib inline

# Load the machine
from os.path import join
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR
#from util.simulation import *
import itertools
import matplotlib.pyplot as plt
from numpy.fft import fft, fftfreq
import numpy as np
machine = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))

# In Jupyter notebook, we set is_show_fig=False to skip call to fig.show() to avoid a warning message
# All plot methods return the corresponding matplotlib figure and axis to further edit the resulting plot
fig, ax = machine.plot(is_show_fig=False)
plt.show()

# %% [markdown]
# On passe à des variation combinée de Rint et Rext,  pour explorer des scénarios complexes.
# tout en gardant toujours  : Rext > Rint
#
# l'épaisseur stator > ~10 mm (0.01 m)

# %%
# les Valeurs originales
print("Rint original :", machine.stator.Rint)
print("Rext original :", machine.stator.Rext)
# Out:
# Rint original : 0.08095
# Rext original : 0.13462

# %%
# Modification en augmentant Rint (+2.0 mm) et réduire Rext (-0.5 mm)
machine.stator.Rint -= 0.002    # +2.0 mm
machine.stator.Rext -= 0.0005   # -0.5 mm

# %%
# Affichage  des  nouvelles valeurs
print("Nouveau Rint :", machine.stator.Rint)
print("Nouveau Rext :", machine.stator.Rext)
# Out:
# Nouveau Rint : 0.07894999999999999
# Nouveau Rext : 0.13412

# %%
# Sauvegarde de la machine modifiée
machine.save("Toyota_Prius_Rint+2.0mm_Rext-0.5mm.json")
# Out:
# [17:57:31] Saving MachineIPMSM to file 'Toyota_Prius_Rint+2.0mm_Rext-0.5mm.json'.
# Saving MachineIPMSM to file 'Toyota_Prius_Rint+2.0mm_Rext-0.5mm.json'.

# %%
----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---------------------------Simulation-----------------------------------------

# %%
# %matplotlib inline

# Load the machine
from os.path import join
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR

IPMSM_A = load("Toyota_Prius_Rint+2.0mm_Rext-0.5mm.json")
# In Jupyter notebook, we set is_show_fig=False to skip call to fig.show() to avoid a warning message
# All plot methods return the corresponding matplotlib figure and axis to further edit the resulting plot
fig, ax = IPMSM_A.plot(is_show_fig=False)
plt.show()

# %%
from os.path import join

from numpy import ones, pi, array, linspace, cos, sqrt

from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.InputCurrent import InputCurrent
from pyleecan.Classes.OPdq import OPdq
from pyleecan.Classes.MagFEMM import MagFEMM

# Create the Simulation
simu_femm = Simu1(name="FEMM_simulation", machine=IPMSM_A)   
# simu_femm.path_result = "path/to/folder" Path to the Result folder to use (will contain FEMM files)
p = simu_femm.machine.stator.winding.p
qs = simu_femm.machine.stator.winding.qs

# Defining Simulation Input
simu_femm.input = InputCurrent()

# Rotor speed [rpm]
N0 = 3000 
simu_femm.input.OP = OPdq(N0=N0)

# time discretization [s]
time = linspace(start=0, stop=60/N0, num=32*p, endpoint=False) # 32*p timesteps
simu_femm.input.time = time 

# Angular discretization along the airgap circonference for flux density calculation
simu_femm.input.angle = linspace(start = 0, stop = 2*pi, num=2048, endpoint=False) # 2048 steps 

# Stator currents as a function of time, each column correspond to one phase [A]
I0_rms = 250/sqrt(2) 
felec = p * N0 /60 # [Hz]
rot_dir = simu_femm.machine.stator.comp_mmf_dir()
Phi0 = 140*pi/180  # Maximum Torque Per Amp

Ia = (
    I0_rms
    * sqrt(2)
    * cos(2 * pi * felec * time + 0 * rot_dir * 2 * pi / qs + Phi0)
)
Ib = (
    I0_rms
    * sqrt(2)
    * cos(2 * pi * felec * time + 1 * rot_dir * 2 * pi / qs + Phi0)
)
Ic = (
    I0_rms
    * sqrt(2)
    * cos(2 * pi * felec * time + 2 * rot_dir * 2 * pi / qs + Phi0)
)
simu_femm.input.Is = array([Ia, Ib, Ic]).transpose()

# %%
from pyleecan.Classes.MagFEMM import MagFEMM

simu_femm.mag = MagFEMM(
    type_BH_stator=0, # 0 to use the material B(H) curve, 
                      # 1 to use linear B(H) curve according to mur_lin,
                      # 2 to enforce infinite permeability (mur_lin =100000)
    type_BH_rotor=0,  # 0 to use the material B(H) curve, 
                      # 1 to use linear B(H) curve according to mur_lin,
                      # 2 to enforce infinite permeability (mur_lin =100000)
    file_name = "", # Name of the file to save the FEMM model
    is_fast_draw=True,  # Speed-up drawing of the machine by using lamination periodicity
    is_sliding_band=True,  # True to use the symetry of the lamination to draw the machine faster
    is_calc_torque_energy=True, # True to calculate torque from integration of energy derivate over rotor elements
    T_mag=60,  # Permanent magnet temperature to adapt magnet remanent flux density [°C]
    is_remove_ventS=False,  # True to remove stator ventilation duct
    is_remove_ventR=False,  # True to remove rotor ventilation duct
)

# Only the magnetic module is defined
simu_femm.elec = None
simu_femm.force = None
simu_femm.struct = None

# %%
simu_femm.mag.is_periodicity_a=True

# %%
simu_femm.mag.is_periodicity_t=True

# %%
simu_femm.mag.nb_worker = 4  # Number of FEMM instances to run at the same time (1 by default)

# %%
simu_femm.mag.is_get_meshsolution = True # To get FEA mesh for latter post-procesing
simu_femm.mag.is_save_meshsolution_as_file = False # To save FEA results in a dat file

# %%
out_femm = simu_femm.run()
# Out:
# [17:58:49] Starting running simulation FEMM_simulation (machine=Toyota_Prius)
# [17:58:49] Starting Magnetic module
# [17:58:50] Computing Airgap Flux in FEMM
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 out_femm = simu_femm.run()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\Simulation\run.py:52, in run(self)
#      49     self.init_logger(results)
#      51     # Compute the simulation
# ---> 52     self.run_single()
#      54 if self.index is None and self.layer == 0:
#      55     msg = "End of simulation"
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\Simu1\run_single.py:31, in run_single(self)
#      29     self.elec.run()
#      30 if self.mag is not None:
# ---> 31     self.mag.run()
#      33 if self.force is not None:
#      34     self.force.run()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\Magnetics\run.py:46, in run(self)
#      44 if Nslices > 1:
#      45     self.get_logger().info("Solving slice 1 / " + str(Nslices))
# ---> 46 out_dict = self.comp_flux_airgap(output, axes_dict, Is_val=Is_val, Ir_val=Ir_val)
#      48 is_loop = True
#      50 if Nslices == 1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\MagFEMM\comp_flux_airgap.py:149, in comp_flux_airgap(self, output, axes_dict, Is_val, Ir_val)
#     139     output.mag.internal.handler_list.remove(femm)
#     140     # With parallelization
#     141     (
#     142         B_elem,
#     143         H_elem,
#     144         mu_elem,
#     145         A_node,
#     146         meshFEMM,
#     147         groups,
#     148         A_elem,
# --> 149     ) = self.solve_FEMM_parallel(
#     150         femm,
#     151         output,
#     152         out_dict,
#     153         FEMM_dict=FEMM_dict,
#     154         sym=sym,
#     155         Nt=Nt,
#     156         angle=angle,
#     157         Is=Is_val,
#     158         Ir=Ir_val,
#     159         angle_rotor=angle_rotor,
#     160         filename=self.import_file,
#     161     )
#     162 else:
#     163     # Without parallelization
#     164     B_elem, H_elem, mu_elem, A_node, meshFEMM, groups, A_elem = self.solve_FEMM(
#     165         femm,
#     166         output,
#    (...)
#     176         filename=self.import_file,
#     177     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\MagFEMM\solve_FEMM_parallel.py:198, in solve_FEMM_parallel(self, femm, output, out_dict, FEMM_dict, sym, Nt, angle, Is, Ir, angle_rotor, filename)
#     196 # Creating threads pool
#     197 with Pool(nb_worker) as p:
# --> 198     results = p.starmap(solve_FEMM_single, args)
#     200 # Building mesh solution
#     201 if self.is_get_meshsolution:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:51, in starmapstar(args)
#      50 def starmapstar(args):
# ---> 51     return list(itertools.starmap(args[0], args[1]))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\MagFEMM\solve_FEMM_parallel.py:113, in solve_FEMM_parallel.<locals>.solve_FEMM_single(femm_handler, filename, start_t, end_t)
#      79 def solve_FEMM_single(femm_handler, filename, start_t, end_t):
#      80     """
#      81     Call FEMM to compute airgap flux density from start_t to end_t timesteps
#      82
#    (...)
#     110
#     111     """
# --> 113     B_elem, H_elem, mu_elem, A_node, meshFEMM, groups, A_elem = self.solve_FEMM(
#     114         femm_handler,
#     115         output,
#     116         out_dict,
#     117         FEMM_dict,
#     118         sym=sym,
#     119         Nt=Nt,
#     120         angle=angle,
#     121         Is=Is,
#     122         Ir=Ir,
#     123         angle_rotor=angle_rotor,
#     124         is_close_femm=True,
#     125         filename=filename,
#     126         start_t=start_t,
#     127         end_t=end_t,
#     128     )
#     130     return B_elem, H_elem, mu_elem, A_node, meshFEMM, groups, A_elem
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Methods\Simulation\MagFEMM\solve_FEMM.py:212, in solve_FEMM(self, femm, output, out_dict, FEMM_dict, sym, Nt, angle, Is, Ir, angle_rotor, is_close_femm, filename, start_t, end_t, Nmess)
#     209     femm.mi_setprevious("", 0)
#     211 # Run the computation
# --> 212 femm.mi_analyze()
#     214 # Load results
#     215 femm.mi_loadsolution()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Classes\_FEMMHandler.py:2169, in _FEMMHandler.mi_analyze(self, *arg)
#    2168 def mi_analyze(self, *arg):
# -> 2169     self.callfemm("mi_analyze" + self.doargs(*arg))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Classes\_FEMMHandler.py:280, in _FEMMHandler.callfemm(self, myString)
#     278 # print(myString) # uncomment to see all the calls made to femm while working
#     279 if is_windows_os:
# --> 280     x = self.callfemm_Windows(myString)
#     281 else:
#     282     x = self.callfemm_Linux(myString)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyleecan\Classes\_FEMMHandler.py:218, in _FEMMHandler.callfemm_Windows(self, myString)
#     216 elif x[0] == "e":
#     217     ErrorMsg = x.replace(",", " ").replace("1j", "I")
# --> 218     raise Exception(ErrorMsg)
#     219 else:
#     220     x = eval(x)
#
# Exception: error: An (anti)periodic BC is assigned to more than two segments

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
